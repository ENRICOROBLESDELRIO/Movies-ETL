# %%
import pandas as pd

# %%
file_dir = './Resources/'

# %%
kaggle_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}ratings.csv')

# %%
kaggle_metadata.sample(n=10)
# Out:
#        adult                              belongs_to_collection    budget  \
# 5761   False  {'id': 374386, 'name': 'Anglo-Zulu War Collect...   3500000
# 6987   False                                                NaN         0
# 24094  False                                                NaN    600000
# 40428  False                                                NaN         0
# 11809  False                                                NaN         0
# 16671  False                                                NaN  30000000
# 5271   False                                                NaN         0
# 13711  False                                                NaN         0
# 12331  False                                                NaN  12000000
# 8341   False                                                NaN         0
#
#                                                   genres  \
# 5761   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 6987   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 24094                [{'id': 99, 'name': 'Documentary'}]
# 40428  [{'id': 27, 'name': 'Horror'}, {'id': 14, 'nam...
# 11809  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 16671  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5271                     [{'id': 37, 'name': 'Western'}]
# 13711                     [{'id': 35, 'name': 'Comedy'}]
# 12331  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 8341   [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
#
#                            homepage      id    imdb_id original_language  \
# 5761                            NaN   14433  tt0058777                en
# 6987                            NaN   10511  tt0298845                en
# 24094                           NaN  288130  tt3983732                en
# 40428                           NaN   78163  tt0125434                ja
# 11809                           NaN   28772  tt0430772                cn
# 16671  http://www.sanctummovie.com/   48340  tt0881320                en
# 5271                            NaN   58455  tt0037627                en
# 13711                           NaN   39194  tt0070605                en
# 12331  http://www.trade-derfilm.de/    4170  tt0399095                en
# 8341                            NaN   28046  tt0024055                en
#
#                         original_title  \
# 5761                              Zulu
# 6987                        In America
# 24094  A Good Job: Stories of the FDNY
# 40428                          ねらわれた学園
# 11809                             旺角黑夜
# 16671                          Sanctum
# 5271                            Dakota
# 13711                       Rhinoceros
# 12331                            Trade
# 8341                         The Ghoul
#
#                                                 overview  ... release_date  \
# 5761   In 1879, during the Zulu wars, man of the peop...  ...   1964-01-22
# 6987   An Irish immigrant family adjusts to life in t...  ...   2003-10-31
# 24094  Acclaimed actor and FDNY veteran Steve Buscemi...  ...   2014-09-08
# 40428  Mitamura Yuka is a normal, shy high school stu...  ...   1981-07-11
# 11809  Hong Kong nihilism. December 22, a street quar...  ...   2004-05-15
# 16671  The 3-D action-thriller Sanctum, from executiv...  ...   2011-02-03
# 5271   In 1871, professional gambler John Devlin elop...  ...   1945-12-25
# 13711  Originally an absurdist play by Eugene Ionesco...  ...   1974-01-21
# 12331  A Texas cop (Kevin Kline), whose own daughter ...  ...   2007-01-23
# 8341   British Egyptologist Professor Morlant finds a...  ...   1933-08-01
#
#            revenue runtime                                   spoken_languages  \
# 5761     8000000.0   138.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 6987           0.0   105.0  [{'iso_639_1': 'ga', 'name': 'Gaeilge'}, {'iso...
# 24094          0.0    60.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 40428          0.0    90.0               [{'iso_639_1': 'ja', 'name': '日本語'}]
# 11809          0.0   110.0  [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'i...
# 16671  108609310.0   108.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 5271           0.0    82.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 13711          0.0   104.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 12331          0.0   120.0  [{'iso_639_1': 'ru', 'name': 'Pусский'}, {'iso...
# 8341           0.0    77.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 5761   Released  Dwarfing the mightiest! Towering over the grea...
# 6987   Released                                                NaN
# 24094  Released                                                NaN
# 40428  Released                                                NaN
# 11809  Released            Fate can bring us together; so can sin!
# 16671  Released                          The only way out is down.
# 5271   Released                  A Romantic Spectacle of the West!
# 13711  Released  The comedy that proves people are still the fu...
# 12331  Released  Each year, more than 1,000,000 people are traf...
# 8341   Released        From the Depths of the Earth, He Will Rise.
#
#                                  title  video vote_average vote_count
# 5761                              Zulu  False          7.4      137.0
# 6987                        In America  False          6.9       97.0
# 24094  A Good Job: Stories of the FDNY  False          0.0        0.0
# 40428         School in the Crosshairs  False          4.0        2.0
# 11809             One Night in Mongkok  False          6.9       14.0
# 16671                          Sanctum  False          5.8      347.0
# 5271                            Dakota  False          4.1       11.0
# 13711                       Rhinoceros  False          7.5        2.0
# 12331                            Trade  False          6.8       69.0
# 8341                         The Ghoul  False          5.0       13.0
#
# [10 rows x 24 columns]

# %%
ratings.sample(n=10)
# Out:
#           userId  movieId  rating   timestamp
# 6307127    65125    44191     4.5  1319466973
# 14383        173    79132     4.5  1443091549
# 21618018  224605     7505     1.5  1359048870
# 18580339  192896     3916     3.0  1078398911
# 13401290  139317   160567     3.5  1482382628
# 7020239    72391     4014     5.0  1496626767
# 16128641  167772     8860     3.5  1471331830
# 23895102  248172      168     3.0   834536009
# 5485836    56571    56782     3.5  1213038426
# 22877616  237659     2571     5.0  1497035533
